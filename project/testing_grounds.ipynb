# %% [markdown]
# # Imports

# %%
import pandas as pd
from aml_final_project.pyAudioAnalysis.pyAudioAnalysis import ShortTermFeatures
from aml_final_project.pyAudioAnalysis.pyAudioAnalysis import MidTermFeatures
from aml_final_project.pyAudioAnalysis.pyAudioAnalysis import audioBasicIO
import matplotlib.pyplot as plt
from pydub import AudioSegment

# %%
filename = '/Users/sam/Documents/CornellTech/Classes/Fall2020/AML/homeworks/aml_final_project/mp4/test.mp4'
new_filename = '/Users/sam/Documents/CornellTech/Classes/Fall2020/AML/homeworks/aml_final_project/wav/test_wav.wav'

sound = AudioSegment.from_file(filename, 'mp4')
sound = sound.set_channels(1)
sound.export(new_filename, format="wav")
# Out:
# <_io.BufferedRandom name='/Users/sam/Documents/CornellTech/Classes/Fall2020/AML/homeworks/aml_final_project/wav/test_wav.wav'>

# %%
[fs, x] = audioBasicIO.read_audio_file(new_filename)

# %%
F, f_names = ShortTermFeatures.feature_extraction(x, fs, 0.050 * fs, 0.025 * fs)

# %%
plt.subplot(2,1,1); plt.plot(F[0,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[0]) 
plt.subplot(2,1,2); plt.plot(F[1,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[1]); plt.show()

# %%
mid_features, wav_files, f_names = MidTermFeatures.directory_feature_extraction('/Users/sam/Documents/CornellTech/Classes/Fall2020/AML/homeworks/aml_final_project/wav',
                                                               1.0, 1.0, 0.050, 0.050)
# Out:
# Analyzing file 1 of 1: /Users/sam/Documents/CornellTech/Classes/Fall2020/AML/homeworks/aml_final_project/wav/test_wav.wav
# Feature extraction complexity ratio: 36.2 x realtime

# %%
len(mid_features)
# Out:
# 138

# %%
len(f_names)
# Out:
# 136

# %%
len(F[0])

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4996ee3d8d09> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google.colab'
